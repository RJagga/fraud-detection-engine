# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../data/creditcard.csv')

print(df.shape)           # (284807, 31)
print(df.dtypes)
print(df.isnull().sum())  # should be 0

# Class distribution — this is the imbalance problem
print(df['Class'].value_counts())
# 0 (legit):  284315  →  99.83%
# 1 (fraud):     492  →   0.17%

# Amount distribution
print(df[df['Class']==1]['Amount'].describe())
print(df[df['Class']==0]['Amount'].describe())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64
